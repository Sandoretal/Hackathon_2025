# %% [markdown]
# # Hackathon 2025

# %% [markdown]
# ### **Advanced** questions
#
# 1. Can demographics and cognitive decline predict motor symptom severity? Which variables are contributing most to the prediction? Is there a difference between PD and Prodromal?
# 2. Can age and GM volume predict cognitive decline?
# 3. You’re a researcher that suspects that one of the food production company in the US might have bene breaching the regulations and using hazardous pesticides that increase the prevalance and severity of Parkinson’s and neurodegeneration in population residing in the region of heir agricultural sites. Using the data at hands, you want to find which region (if any) has higher severity of neurodegeneration ? Use the supplementary table linking the clinic name to the regions they’re located in (we assume that the patient lives in the same region asthe clinic), and perform a suitable statistical analysis to find out if your suspicions are true and in what region this crime might be occurring?

# %% [markdown]
# # 1. Can demographics and cognitivie decline predict motor symptom severity? Which variables are contributing most to the prediction? Is there a difference between PD and Prodromal?

# %% [markdown]
# # 2. Can age and GM volume predict cognitive decline?

# %% [markdown]
# ## Final Challenge!
# You’re a researcher that suspects that one of the food production company in the US might have been breaching the regulations and using hazardous pesticides that increase the prevalance and severity of Parkinson’s and neurodegeneration in population residing in the region of their agricultural sites.
# * Using the data at hands, you want to find which region (if any) has higher severity of neurodegeneration ?
# * Use the supplementary table linking the clinic name to the regions they’re located in (we assume that the patient lives in the same region as the clinic), and perform a suitable statistical analysis to find out if your suspicions are true and in what region this crime might be occurring? You will get extra points for only using string methods to clean the clinic names and match them to the lookup table.
