# %% [markdown]
# # Hackathon 2025

# %% [markdown]
# ### **Easy** questions
#
# 1. Perform Data cleaning:
#     * How many duplicates are there in the data? What type of duplicates are they?
#     * How many missing values are there in the data? What type of missingness is it?
#     * Find outliers in the data. What statistical approach did you use for it and why?
#
# 2. What is the demographic distribution of the Parkinson's Disease and Prodromal cohorts in the raw data (after dropping the duplicates and outliers, but without any imputation)?
#     * Any difference bebtween PD and Prod?
#     * Visualise it and describe the distributions with appropriate statistics
# 3. What is the distribution of MoCA and/or UPDRS scores of Parkinson's Disease and Prodromal cohorts in the raw data (after dropping the duplicates and outliers, but without any imputation)?
#     * Are there any difference between PD and Prod? Visualise it and describe the distributions with appropriate statistics.
#     * Perform the analysis relative to severety categories as well.

# %% [markdown]
# The dataset variables:
#
# 1. PANTO: patient's number
# 2. SEX: 1=Male, 0=Female
# 3. HANDED: Handedness: 1=Right, 2=Left, 3=Mixed
# 4. COHORT_DEFINITION: 'Parkinson''s Disease' / 'Prodromal'
# 5. ENROLL_AGE: patient's age
# 6. NP3TOT: patient's UPDRSIII score
# 7. MCATOT: patient's MoCA scores
# 8. GMvol: patient's total grey matter volume (mm^3) for patients with an MRI scan at baseline, for the rest this column is NaN.
#
#
# Severity Scales:
#
# UPDRSIII scale: Range - 0-132,   Mild <32;   Moderate 32-59; Severe >59
#
# MoCA scale:     Range - 0-30, Normal 26-30;   Mild 18-25; Moderate 10-17; Severe <10

# %%
import pandas as pd 
import numpy as np 
from scipy import stats

df = pd.read_csv('ppmi_hack_dirty.csv')
df
# Out:
#        PATNO  SEX  HANDED    COHORT_DEFINITION  ENROLL_AGE  NP3TOT  MCATOT  \
# 0       3001  1.0     NaN  Parkinson's Disease        65.1     NaN    29.0
# 1       3002  0.0     1.0  Parkinson's Disease        67.6     NaN    27.0
# 2       3003  0.0     1.0  Parkinson's Disease        56.7    29.0    25.0
# 3       3006  0.0     1.0  Parkinson's Disease        57.5     NaN    27.0
# 4       3007  1.0     2.0  Parkinson's Disease        64.5    21.0    29.0
# ...      ...  ...     ...                  ...         ...     ...     ...
# 4246  149940  NaN     1.0  Parkinson's Disease        63.6     NaN    26.0
# 4247   60114  NaN     1.0            Prodromal         NaN    12.0    27.0
# 4248  217776  1.0     1.0            Prodromal         NaN     NaN     NaN
# 4249  214777  0.0     2.0            Prodromal        66.5    -1.0    26.0
# 4250  184507  1.0     1.0  Parkinson's Disease        65.3    38.0     NaN
#
#       GMvol clinic_id
# 0       NaN   CLIN007
# ...

# %% [markdown]
# ## 1. Data Cleaning
#
# Clean the dataframe accordingly and explain your reasoning.

# %% [markdown]
# ### How many duplicates are there in the data? What type of duplicates are they?

# %% [markdown]
# ### How many missing values are there in the data? What type of missingness is it?

# %% [markdown]
# ## 2. Find outliers in the data. What statistical approach did you use for it and why?

# %% [markdown]
# ## 3. What is the demographic distribution of the Parkinson's Disease and Prodromal cohorts in the raw data (after dropping the duplicates and outliers, but without any imputation)?

# %% [markdown]
# ## 4. What is the distribution of MoCA and UPDRS scores? Do these relative to severety categories. Produce and visualise some descriptive statistics
